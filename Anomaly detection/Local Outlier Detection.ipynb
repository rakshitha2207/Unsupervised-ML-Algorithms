# %%
from sklearn.neighbors import LocalOutlierFactor
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_moons

# %%
# Generate make_moons dataset
X, _ = make_moons(n_samples=300, noise=0.1, random_state=42)

# %%
# Apply Local Outlier Factor
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.1)
y_pred = lof.fit_predict(X)
outliers = y_pred == -1

# %%
# Scatter plot
plt.figure(figsize=(10, 6))

# Plot inliers
plt.scatter(X[~outliers, 0], X[~outliers, 1], color='blue', label='Inliers')

# Plot outliers
plt.scatter(X[outliers, 0], X[outliers, 1], color='red', label='Outliers')

plt.title('Outlier Detection with Local Outlier Factor on make_moons')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
